# %% [markdown]
# # 1. Comprensión del Negocio
#
# Fase puramente conceptual: antes de tocar los datos definimos qué problema resolvemos, qué éxito mediremos y qué hipótesis validaremos.

# %% [markdown]
# ## 1.1 Contexto
#
# YouTube es una de las plataformas de contenido más grandes del mundo. Para una agencia de marketing digital, entender qué hace que un video aparezca en tendencias permite optimizar estrategias de contenido, presupuesto de pauta y selección de influencers.

# %% [markdown]
# ## 1.2 Objetivo de negocio
#
# - Comprender los factores que explican el éxito de un video en tendencias.
# - Identificar categorías y canales más rentables.
# - Detectar patrones temporales y geográficos.
# - Construir un modelo predictivo de `views`.

# %% [markdown]
# ## 1.3 KPIs
#
# - `avg_views`: promedio de vistas por categoría.
# - `avg_likes`: promedio de likes por categoría.
# - `engagement_rate`: (likes + dislikes + comments) / views.
# - `like_dislike_ratio`: likes / (dislikes + 1).
# - `comments_per_view`: comments / views.
# - `days_to_trending`: días entre publicación y trending.
# - `trending_frequency`: apariciones por canal.

# %% [markdown]
# ## 1.4 Hipótesis iniciales
#
# | ID | Hipótesis |
# |----|-----------|
# | H1 | Entertainment y Music concentran más vistas. |
# | H2 | Mayor engagement implica mayor número de vistas. |
# | H3 | Los videos recientes llegan más rápido a tendencias. |
# | H4 | Unos pocos canales dominan la sección trending (Pareto). |
# | H5 | Existen diferencias significativas entre regiones del UK. |

# %% [markdown]
# ## 1.5 Objetivo de Data Science
#
# **Variable dependiente (a predecir):**
# - `views` — número de vistas del video. Es la métrica principal de éxito/viralidad solicitada por el cliente.
#
# **Variables independientes principales (≥ 4, incluyendo derivadas):**
#
# | Variable | Origen | Tipo |
# |----------|--------|------|
# | `likes` | Original | Interacción |
# | `comment_count` | Original | Interacción |
# | `category_name` | Derivada (mapeo del JSON) | Categórica |
# | `like_dislike_ratio` = likes / (dislikes + 1) | **Derivada** | Ratio |
# | `days_to_trending` = trending_date − publish_time | **Derivada** | Temporal |
# | `engagement_rate` = (likes+dislikes+comments) / views | **Derivada** | Ratio |
# | `state` | Original (geográfica) | Categórica |
#
# **Técnica:** regresión supervisada, comparando varios algoritmos (lineal, árboles, ensembles) y evaluando con MAE, RMSE y R².

# %%
print('Fase 1 completada: objetivos, KPIs e hipótesis definidos.')
